# %% [markdown]
# # Limpieza del dataset

# %% [markdown]
# ## 1.Carga y análisis del CSV original

# %%
# Importamos libreria pandas y numpy
import pandas as pd
import numpy as np

# %%
# Subimos el archivo a nuestro proyecto
df = pd.read_csv("/content/ofertas-empleo (1).csv")

# Obtenemos las columnas del df y las convertirmos en una lista para visualizarlas claramente
df.columns.values.tolist()
# Out:
# ['country_code',
#  'title',
#  'job_category',
#  'description',
#  'company_name',
#  'city',
#  'contract_type',
#  'workday',
#  'salary_min',
#  'salary_max',
#  'salary_period',
#  'salary_currency',
#  'salary_type',
#  'remote',
#  'publish_date']

# %%
# Mostramos las primeras 3 filas del DataFrame para tener una vista previa de los datos
df.head(3)
# Out:
#   country_code                                              title  \
# 0           es                      Técnico Gestión de la Demanda
# 1           es  Java - SpringBoot - Proyecto estable - Teletra...
# 2           es            Consultor SAP Hana Ingles Alto (Remoto)
#
#                        job_category  \
# 0  Informática y telecomunicaciones
# 1  Informática y telecomunicaciones
# 2  Informática y telecomunicaciones
#
#                                          description  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
#
#                  company_name    city        contract_type           workday  \
# 0  Atento España - Estructura  Madrid  Contrato indefinido  Jornada completa
# 1      AGIO GLOBAL TECHNOLOGY  Madrid  Contrato indefinido  Jornada completa
# 2         AIRON Sistemas S.L.  Madrid  Contrato indefinido  Jornada completa
#
#    salary_min  salary_max salary_period salary_currency salary_type  \
# 0         NaN         NaN           NaN             NaN         NaN
# 1     40000.0     45000.0          YEAR             EUR       GROSS
# 2     27000.0     30000.0          YEAR             EUR       GROSS
#
#              remote publish_date
# 0           Híbrido   2022-07-12
# 1  Solo teletrabajo   2022-07-12
# 2  Solo teletrabajo   2022-07-12

# %%
# Imprime la forma del DataFrame, mostrando el número de filas y columnas
df.shape
# Out:
# (10000, 15)

# %%
# Muestra los tipos de datos de cada columna en el DataFrame
print(f">>> Tipo de columnas:\n{df.dtypes}\n")
# Out:
# >>> Tipo de columnas:
# country_code        object
# title               object
# job_category        object
# description         object
# company_name        object
# city                object
# contract_type       object
# workday             object
# salary_min         float64
# salary_max         float64
# salary_period       object
# salary_currency     object
# salary_type         object
# remote              object
# publish_date        object
# dtype: object

# %%
# Proporciona un resumen conciso del DataFrame
# incluyendo la cantidad de valores no nulos y el tipo de dato por columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country_code     10000 non-null  object
#  1   title            10000 non-null  object
#  2   job_category     10000 non-null  object
#  3   description      10000 non-null  object
#  4   company_name     10000 non-null  object
#  5   city             9999 non-null   object
#  6   contract_type    4647 non-null   object
#  7   workday          4647 non-null   object
#  8   salary_min       4286 non-null   float64
#  9   salary_max       4162 non-null   float64
#  10  salary_period    6988 non-null   object
#  11  salary_currency  6988 non-null   object
#  12  salary_type      1635 non-null   object
#  13  remote           4053 non-null   object
#  14  publish_date     10000 non-null  object
# dtypes: float64(2), object(13)
# memory usage: 1.1+ MB

# %%
# Genera estadísticas descriptivas que resumen
# la tendencia central, la dispersión y la forma de la distribución de un conjunto de datos
df.describe()
# Out:
#          salary_min    salary_max
# count  4.286000e+03  4.162000e+03
# mean   6.034396e+04  8.619583e+04
# std    1.511560e+05  1.823247e+05
# min    1.200000e+01  1.200000e+01
# 25%    2.500000e+04  3.202525e+04
# 50%    3.600000e+04  4.800000e+04
# 75%    6.318850e+04  9.390825e+04
# max    7.500000e+06  7.501000e+06

# %% [markdown]
# ## 2.Limpieza de datos

# %% [markdown]
# ### 2.1 Eliminamos duplicados y tratamos valores nulos

# %%
# ELIMINACION DUPLICADOS

# En esta sección identificamos y eliminamos filas duplicadas en el dataset.
# Se analizan tanto duplicados exactos como duplicados que sean la misma oferta.

# %%
# Calculo el número de filas completamente duplicadas
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Confirmo que no tengo duplicados igual
df[df.duplicated()]

# Al saltar solo el nombre de las columnas confirmo que no tengo filas duplicadas exactas
# El resultado es un df en el que NO tiene duplicados exactos, NO se han elimando filas en esta fase
# Out:
# Empty DataFrame
# Columns: [country_code, title, job_category, description, company_name, city, contract_type, workday, salary_min, salary_max, salary_period, salary_currency, salary_type, remote, publish_date]
# Index: []

# %%
# Buscamos si tenemos ofertas que sus filas no sean exactamente igual pero si esten repetidas.

revision_cols = ['title', 'company_name', 'city', 'publish_date']  # Revisamos estas columnas, porque si coincide seria la misma oferta repetida

df[df.duplicated(subset=revision_cols, keep=False)] # Buscamos las filas repetidas de las columnas seleccionadas en la lista revision_cols


# Consideramos que una oferta es única si coincide en:
# ['title', 'company_name', 'city', 'publish_date'].

# Vemos varias ofertas que coinciden en todos los campos excepto en ('contract_type'y 'remote'). Mantendremos solo una fila de estas ofertas.
# Out:
#      country_code                        title  \
# 17             es   Técnico/a Microinformático
# 94             es   Técnico/a Microinformático
# 6171           es  Network & Security Operator
# 6172           es  Network & Security Operator
#
#                           job_category  \
# 17    Informática y telecomunicaciones
# 94    Informática y telecomunicaciones
# 6171  Informática y telecomunicaciones
# 6172  Informática y telecomunicaciones
#
#                                             description  company_name  \
# 17    ¡Te invitamos a formar parte de nuestro equipo...      Sermicro
# 94    ¡Te invitamos a formar parte de nuestro equipo...      Sermicro
# 6171  SEIDOR, multinacional española en plena expans...  Grupo Seidor
# 6172  SEIDOR, multinacional española en plena expans...  Grupo Seidor
#
#            city              contract_type           workday  salary_min  \
# 17       Madrid   Contrato otros contratos  Jornada completa         NaN
# 94       Madrid  Contrato fijo discontinuo  Jornada completa         NaN
# 6171  Barcelona        Contrato indefinido  Jornada completa         NaN
# 6172  Barcelona        Contrato indefinido  Jornada completa         NaN
#
#       salary_max salary_period salary_currency salary_type      remote  \
# 17           NaN           NaN             NaN         NaN  Presencial
# 94           NaN           NaN             NaN         NaN  Presencial
# 6171         NaN           NaN             NaN         NaN         NaN
# 6172         NaN           NaN             NaN         NaN  Presencial
#
#      publish_date
# 17     2022-07-12
# 94     2022-07-12
# 6171   2022-08-03
# 6172   2022-08-03

# %%
# Eliminamos duplicados con ofertas repetidas en los campos('title', 'company_name', 'city', 'publish_date').

# Conservaremos la segunda aparicion de las ofertas por consideras datos mas completos

df = df.drop_duplicates(subset=revision_cols, keep='last')

# %%
# Buscamos cuantos valores nulos tenemos en cada columna del df:
df.isnull().sum()
# Out:
# country_code          0
# title                 0
# job_category          0
# description           0
# company_name          0
# city                  1
# contract_type      5353
# workday            5353
# salary_min         5712
# salary_max         5836
# salary_period      3010
# salary_currency    3010
# salary_type        8363
# remote             5946
# publish_date          0
# dtype: int64

# %%
# Hacemos limpieza de ciertas columnas que tiene nulos sustituyendolo por 'No publicado'

df['contract_type'] = df['contract_type'].fillna('No publicado')
df['workday'] = df['workday'].fillna('No publicado')
df['remote'] = df['remote'].fillna('No publicado')

# Las columnas seleccionadas es normal que no se publiquen estos datos en las ofertas de las empresas
# Al mantener las columnas con otra categoria 'No publicado', nos da otra información util:
#  -Mantenemos toda la informacion
#  -Nueva categoria dentro de las columna
#  -Mejor analisis con la información mas completa
#  -Mejor visualización posterior en POWER BI y otros analisis cuando hagamos webscraping


# La columna 'city' tiene un nulo que no tiene sentido. Elminamos dicha fila que no afecta al análisis para que despues
# no tengamos problemas si queremos agrupar por ciudades en el EDA o en el POWER BI entre otras cosas.

df = df.dropna(subset=['city'])

df.isnull().sum()
# Out:
# country_code          0
# title                 0
# job_category          0
# description           0
# company_name          0
# city                  0
# contract_type         0
# workday               0
# salary_min         5711
# salary_max         5835
# salary_period      3010
# salary_currency    3010
# salary_type        8362
# remote                0
# publish_date          0
# dtype: int64

# %% [markdown]
# ###2.2 Corregimos datos incorrectos

# %%
# CORREGIR DATOS INCORRECTOS
# Comprobamos los salarios

# Ni el salario minimo ni el maximo puede ser menor que cero

df[(df['salary_min'] < 0) |(df['salary_max']< 0)]


# Como sales el df vacio comprobamos que los salarios estan correctos segun estas comprobaciones
# Out:
# Empty DataFrame
# Columns: [country_code, title, job_category, description, company_name, city, contract_type, workday, salary_min, salary_max, salary_period, salary_currency, salary_type, remote, publish_date]
# Index: []

# %%
# El salario maximo no puede ser menos que el salario minimo

df[df['salary_max'] < df['salary_min']] # Como sales el df vacio comprobamos que los salarios estan correctos segun estas comprobaciones
# Out:
# Empty DataFrame
# Columns: [country_code, title, job_category, description, company_name, city, contract_type, workday, salary_min, salary_max, salary_period, salary_currency, salary_type, remote, publish_date]
# Index: []

# %% [markdown]
# ## 3.Unificacion de formatos

# %%
# En este bloque vamos a tratar la unificación de formatos para estandarizar el data set mediante la corrección de formatos (fechas,salarios y
# eliminación de símbolos)

# Convertimos la columna a un tipo fecha indicando que está en formato americano
df["publish_date"] = pd.to_datetime(df["publish_date"], dayfirst=False)
# pd.to_datetime() convierte una columna de texto en objetos de fecha (datetime).dayfirst=False indica que el primer número no es el día, sino el mes.

# %%
# Formatos de salario

# En algunas columnas puede aparecer algo como "30.000 €"
# Queremos dejarlo como "30000" (sin espacios ni símbolo)

# Primero, eliminamos símbolos € y espacios
df["salary_min"] = df["salary_min"].astype(str).str.replace("€", "", regex=False).str.strip()
df["salary_max"] = df["salary_max"].astype(str).str.replace("€", "", regex=False).str.strip()

# Convertimos a número directamente (NaN si no se puede)
df["salary_min"] = pd.to_numeric(df["salary_min"], errors='coerce')
df["salary_max"] = pd.to_numeric(df["salary_max"], errors='coerce')

# Redondeamos para quitar posibles decimales y convertimos a Int64
df["salary_min"] = df["salary_min"].round().astype("Int64")
df["salary_max"] = df["salary_max"].round().astype("Int64")


# No surge el siguiente problema respecto a las columnas de salarios y es
# que en Pandas no se puede tener una columna con enteros y NaN al mismo tiempo usando el tipo int
# Lo hemos solucionado usando el tipo Int64 de Pandas, que permite enteros y valores nulos (<NA>). Así no vemos .0.

# %%
# Aquí quitamos:
# - Saltos de línea (\n)
# - Tabulaciones (\t)
# - Comillas dobles (")
# - Comillas simples (')
# - Espacios repetidos

columnas_texto = [    "title", "job_category", "description", "company_name",
    "city", "contract_type", "workday", "remote"]

for col in columnas_texto:

    # Convertimos la columna a texto por si hay valores no textuales
    df[col] = df[col].astype(str)

    # Quitamos saltos de línea
    df[col] = df[col].str.replace("\n", " ", regex=False)

    # Quitamos tabulaciones
    df[col] = df[col].str.replace("\t", " ", regex=False)

    # Quitamos comillas dobles y simples
    df[col] = df[col].str.replace('"', "", regex=False)
    df[col] = df[col].str.replace("'", "", regex=False)

    # Quitamos espacios repetidos dejando solo uno
    df[col] = df[col].str.replace("  ", " ", regex=False)

    # Quitamos espacios al principio y al final
    df[col] = df[col].str.strip()

# %% [markdown]
# ## 4.Normalizacion de texto

# %% [markdown]
# ### 4.1 Conversión a minúsculas y eliminación tildes, acentos y caracteres especiales

# %%
# En este bloque estandarizamos todas las columnas de texto convirtiéndolas a minúsculas
# y eliminando tildes, acentos y caracteres especiales.
# Función homogeneizar
# En esta parte nos hemos centrado en poner todo el texto a minúscula y quitar los acentos
import re # Módulo de expresiones regulares, que nos permite trabajar con patrones de textos complejos.

def normalizar_texto(texto):
    if not isinstance(texto, str):
        return texto

    texto = texto.lower()

    # Reemplazar acentos
    acentos = {
        "á": "a",
        "é": "e",
        "í": "i",
        "ó": "o",
        "ú": "u",
        "ü": "u"
    }
    for a, s in acentos.items():
        texto = texto.replace(a, s)

    return texto

# %%
# Aplicamos de forma automática a todas las columnas tipo texto

for col in df.columns:
    if df[col].dtype == "object":  # solo columnas de texto
        df[col] = df[col].apply(normalizar_texto)

# %%
# Cambiamos el formato del salario para que no aparezca el decimal

cols_salario = ["salary_min", "salary_max"]

for col in cols_salario:
    df[col] = pd.to_numeric(df[col], errors="coerce").astype("Int64")

# %% [markdown]
# ### 4.2 Columna "workday"

# %%
#Observamos los posibles datos que aparecen en la columna "workday" (tipo de jornada laboral)
df["workday"].value_counts(dropna=False)
# Out:
# workday
# no publicado                       5352
# jornada completa                   4410
# jornada indiferente                  87
# jornada intensiva - mañana           63
# jornada parcial - mañana             36
# jornada parcial - indiferente        19
# jornada intensiva - indiferente      16
# jornada parcial - tarde               7
# jornada intensiva - tarde             4
# jornada intensiva - noche             3
# Name: count, dtype: int64

# %%
#Ya que hay varios nombres similares, hacemos modificaciones para unificar nombres
#y quedarnos con dos categorías amplias ("full_time" y "part_time"), sin modificar los nulos.

df.loc[df["workday"].str.contains("completa|intensiva"), "workday"] = "completa"
df.loc[df["workday"].str.contains("parcial"), "workday"] = "parcial"
df.loc[df["workday"].str.contains("indiferente"), "workday"] = "otra"

# %%
#Vemos los datos que tenemos ahora con los cambios ya hechos
df["workday"].value_counts()
# Out:
# workday
# no publicado    5352
# completa        4496
# otra              87
# parcial           62
# Name: count, dtype: int64

# %% [markdown]
# ### 4.3 Columna "remote"

# %%
#Vemos también cuántos datos aparecen en la columna "workday" (presencialidad)
df["remote"].value_counts()
# Out:
# remote
# no publicado               5945
# presencial                 1869
# hibrido                    1360
# solo teletrabajo            817
# trabajo solo presencial       6
# Name: count, dtype: int64

# %%
#Volvemos a simplificar nombres y los cambiamos a inglés por coherencia con otros datos
df.loc[df["remote"].str.contains("híbrido"), "remote"] = "hibrido"
df.loc[df["remote"].str.contains("teletrabajo"), "remote"] = "remoto"
df.loc[df["remote"].str.contains("presencial"), "remote"] = "presencial"

# %%
#Vemos los datos que tenemos ahora con los cambios ya hechos
df["remote"].value_counts(dropna=False)
# Out:
# remote
# no publicado    5945
# presencial      1875
# hibrido         1360
# remoto           817
# Name: count, dtype: int64

# %%
#Y ahora cambiamos el orden de las columnas para que remote aparezca con las demás columnas
#que nos dan información sobre el puesto de trabajo

cols = df.columns.tolist()
if "remote" in cols:
    cols.remove("remote")
idx = cols.index("workday") + 1
cols.insert(idx, "remote")
df = df[cols]

# %%
df.head()
# Out:
#   country_code                                              title  \
# 0           es                      tecnico gestion de la demanda
# 1           es  java - springboot - proyecto estable - teletra...
# 2           es            consultor sap hana ingles alto (remoto)
# 3           es        android developer. ingles alto. 100% remoto
# 4           es                        analista funcional temporal
#
#                        job_category  \
# 0  informatica y telecomunicaciones
# 1  informatica y telecomunicaciones
# 2  informatica y telecomunicaciones
# 3  informatica y telecomunicaciones
# 4  informatica y telecomunicaciones
#
#                                          description  \
# 0  -definicion de roles y escenarios\r    - docum...
# 1  desde agioglobal technology, nos encontramos e...
# 2  airon compañia de innovacion servicios tecnolo...
# 3  desde modis it consultora global especializada...
# 4  nuevas aplicaciones/extension de la funcionali...
#
#                  company_name    city        contract_type   workday   remote  \
# 0  atento españa - estructura  madrid  contrato indefinido  completa  hibrido
# 1      agio global technology  madrid  contrato indefinido  completa   remoto
# 2         airon sistemas s.l.  madrid  contrato indefinido  completa   remoto
# 3                       modis  madrid  contrato indefinido  completa   remoto
# 4  atento españa - estructura  madrid  contrato indefinido  completa  hibrido
#
#    salary_min  salary_max salary_period salary_currency salary_type  \
# 0        <NA>        <NA>           NaN             NaN         NaN
# 1       40000       45000          year             eur       gross
# 2       27000       30000          year             eur       gross
# 3        <NA>        <NA>           NaN             NaN         NaN
# 4       24000       27000          year             eur       gross
#
#   publish_date
# 0   2022-07-12
# 1   2022-07-12
# 2   2022-07-12
# 3   2022-07-12
# 4   2022-07-12

# %% [markdown]
# ### 4.4 Unificación de las categorías laborales

# %%
# 1. Vamos a unificar categorías del CSV original en una columna nueva
#para conservar los datos originales:
df.loc[:, "job_sector"] = "other"


# 2. Aplicamos filtros en cada una de las tres nuevas categorías, con un "cajón" donde meter los puestos
#que aparecen con mayor frecuencia
patron_it = r"software|desarrollador|developer|java|programador|\bqa\b|devops|fullstack|dba|scrum|backend|frontend|sistemas|\bit\b|informático|informatico|soporte|helpdesk|onsite|vdi"
filtro_it = df["title"].str.contains(patron_it, case=False, na=False, regex=True)

patron_executive = r"\bdirector\b|\bceo\b|\bcto\b|head|\bvp\b|chief"
filtro_executive = df["title"].str.contains(patron_executive, case=False, na=False, regex=True)

patron_data = r"data|datos|analytics|analyst|analista|\bbi\b|\bai\b|intelligence|machine learning"
filtro_data = df["title"].str.contains(patron_data, case=False, na=False, regex=True)

patron_engineering = r"engineering|engineer|hardware|embedded|automation|robotics"
filtro_engineering = df["title"].str.contains(patron_engineering, case=False, na=False, regex=True)

# 3. Cambiamos cada categoría en orden
df.loc[filtro_engineering, "job_sector"] = "engineering"
df.loc[filtro_data, "job_sector"] = "data"
df.loc[filtro_executive, "job_sector"] = "executive"
df.loc[filtro_it, "job_sector"] = "software"

# 4. Cambiamos el orden de la columna para que esté junto a job_category

cols = df.columns.tolist()
if "job_sector" in cols:
    cols.remove("job_sector")
idx = cols.index("job_category") + 1
cols.insert(idx, "job_sector")
df = df[cols]

# %%
df["job_sector"].value_counts().head(50).reset_index()
# Out:
#     job_sector  count
# 0        other   5696
# 1     software   2826
# 2         data    788
# 3  engineering    492
# 4    executive    195

# %%
df[df["job_sector"] == "data"]["title"].value_counts().head(30)
# Out:
# title
# business analyst                                                                                              13
# data engineer                                                                                                  9
# data scientist                                                                                                 7
# data analyst                                                                                                   6
# senior data engineer                                                                                           5
# systems support analyst                                                                                        5
# take up - business analyst junior con frances                                                                  4
# senior pricing analyst (remote)                                                                                4
# analista funcional                                                                                             4
# senior data engineer - business intelligence / sql / python / remote (m/w/d)                                   4
# application support analyst - remote usa                                                                       4
# consultor/a tecnologia y modelado datos business intelligence (powercenter, odi, power bi, obiee, ssis..)      4
# systems support analyst - remote uk                                                                            4
# scientific applications support senior analyst                                                                 3
# big data engineer - technical support - google cloud - (barcelona)                                             3
# systems analyst                                                                                                3
# apple media products - senior machine learning research engineer (graph)                                       3
# master data analyst                                                                                            3
# database administrator                                                                                         3
# operations analyst - temporary                                                                                 3
# data architect                                                                                                 3
# operations analyst                                                                                             3
# big data engineer                                                                                              3
# data engineer - remoto (,)                                                                                     2
# hr analytics consultant                                                                                        2
# consultor/a tecnologia y modelado datos business intelligence (powercenter, odi, power bi, obiee, ssis..).     2
# analyst, appl architect                                                                                        2
# lead analytics consultant                                                                                      2
# payroll analyst - europe - london                                                                              2
# technical support analyst - remote - uk                                                                        2
# Name: count, dtype: int64

# %% [markdown]
# ## 5.Creación y eliminación de columnas

# %% [markdown]
# ### 5.1 Position_level

# %%
"""La creación de position_level es una decisión metodológica orientada a enriquecer el análisis,
permitiendo agrupar las ofertas por nivel del puesto a partir del título.
Al tratarse de una inferencia y no de un dato original, su uso es opcional y se limita a análisis descriptivos.
"""

t = df["title"].fillna("").str.upper()

df["position_level"] = pd.NA

# Definición de palabras clave
exec_kw = r"\bdirector\b|\bhead\b|\bvp\b|\bvice president\b|\bcio\b|\bcto\b|\bceo\b|\bcfo\b|\bcoo\b|\bchief\b"
mgmt_kw = r"\bmanager\b|\bgerente\b|\bresponsable\b|\blead\b|\blider\b|\blíder\b|\bcoordinador\b|\bcoordinadora\b|\bsupervisor\b|\bsupervisora\b|\bjefe\b|\bjefa\b"
tech_kw = r"\bdeveloper\b|\bdesarrollador\b|\bdesarrolladora\b|\bengineer\b|\bingeniero\b|\bingeniera\b|\banalyst\b|\banalista\b|\bconsultor\b|\bconsultora\b|\bprogramador\b|\bprogramadora\b|\bdata\b|\bdevops\b|\bandroid\b|\bios\b|\bfrontend\b|\bbackend\b|\bfullstack\b|\bqa\b|\btester\b|\barquitecto\b|\barquitecta\b|\badministrador\b|\badministradora\b|\bsystem\b|\bsistemas\b|\bsap\b"
intern_kw = r"\bbeca\b|\bprácticas\b|\bpracticas\b|\bintern\b|\binternship\b|\btrainee\bb"

# Asignación de niveles en minúsculas
df.loc[t.str.contains(exec_kw, regex=True, case=False), "position_level"] = "executive"
df.loc[t.str.contains(mgmt_kw, regex=True, case=False), "position_level"] = "management"
df.loc[t.str.contains(tech_kw, regex=True, case=False), "position_level"] = "technical"
df.loc[t.str.contains(intern_kw, regex=True, case=False), "position_level"] = "internship"

# Cambio de orden de la columna
cols = df.columns.tolist()
if "position_level" in cols:
    cols.remove("position_level")
idx = cols.index("salary_min") - 1
cols.insert(idx, "position_level")
df = df[cols]

# %%
df["position_level"].value_counts(dropna=False)
# Out:
# position_level
# <NA>          4085
# technical     4085
# management    1467
# executive      190
# internship     170
# Name: count, dtype: int64

# %% [markdown]
# ###5.2 Modificación de datos de país

# %%
#Veamos cuántos países se incluyen en nuestro df
df["country_code"].value_counts()
# Out:
# country_code
# es    6172
# us    1264
# uk     857
# sg     553
# de     368
# fr     335
# in     203
# nl     136
# ie      99
# mx      10
# Name: count, dtype: int64

# %%
#Y ahora las ciudades fuera de España
df[df["country_code"] != "es"]["city"].value_counts()
# Out:
# city
# london, england        566
# singapore              553
# austin, tx             291
# paris                  246
# boston, ma             206
# mumbai                 203
# atlanta, ga            174
# munchen                152
# los angeles, ca        141
# chicago, il            108
# houston, tx            102
# berlin                  86
# leeds, england          76
# lyon                    75
# koln                    73
# dublin                  70
# stuttgart               52
# rotterdam               51
# birmingham, england     46
# utrecht                 44
# miami, fl               40
# denver, co              39
# glasgow, scotland       38
# bristol, england        36
# sacramento, ca          32
# new york, ny            29
# cork                    29
# liverpool, england      29
# manchester, england     26
# edinburgh, scotland     25
# eindhoven               22
# philadelphia, pa        22
# orlando, fl             15
# salt lake city, ut      15
# cardiff, wales          15
# marseille               14
# nashville, tn           13
# amsterdam               12
# dallas, tx              12
# indianapolis, in        12
# san antonio, tx         11
# den haag                 7
# ciudad de mexico         6
# frankfurt am main        5
# tijuana                  4
# portland, or             1
# seattle, wa              1
# Name: count, dtype: int64

# %%
#A partir de los datos obtenidos, se decide hacer el análisis de:

#1. España, por ser el mercado con más ofertas y que, además,
#es más importante según lo indicado en el guion de trabajo

#2. Londres y París, por ser las ciudades europeas con mayor volumen de trabajo
#y por proximidad geográfica.

# %%
#Para empezar, nos quedamos solo con los tres países que contienen estas ofertas
df = df[df["country_code"].isin(["es", "uk", "fr"])]

# %%
#Verificamos que tenemos los países correctos
df["country_code"].value_counts()
# Out:
# country_code
# es    6172
# uk     857
# fr     335
# Name: count, dtype: int64

# %%
#Por último, eliminamos los registros de UK y de FR que no pertenencen ni a Londres ni a París
df = df[~((df["country_code"].isin(["uk", "fr"])) & (~df["city"].isin(["london, england", "paris"])))]

# %%
df["country_code"].value_counts()
# Out:
# country_code
# es    6172
# uk     566
# fr     246
# Name: count, dtype: int64

# %%
#Comprobamos las filas y columnas que tenemos ahora en total
df.shape
# Out:
# (6984, 18)

# %% [markdown]
# ###5.3 Annual salary

# %%
"""Vemos que no todos están por año, así que vamos a crear una nueva columna
que convierta el sueldo a anual, a partir de la media entre sueldo mínimo y máximo.
numpy nos permite convertir los sueldos no anuales a anuales, multiplicando por el número correspondiente
dependiendo de si es mensual o por hora, y manteniendo el valor tal cual si ya es anual
o si falta el sueldo mínimo o el máximo
"""

df["annual_salary"] = np.where(df["salary_period"] == "year",
    df[['salary_min', 'salary_max']].mean(axis=1, skipna=True),
      np.where(df["salary_period"] == "month",
         df[['salary_min', 'salary_max']].mean(axis=1, skipna=True) * 12,
            np.where(df["salary_period"] == "hour", df[['salary_min', 'salary_max']].mean(axis=1, skipna=True) * 2080,
            np.nan)))

# %%
#Y ahora colocamos la nueva columna después de salary_max

cols = df.columns.tolist()
if 'annual_salary' in cols:
    cols.remove('annual_salary')
idx = cols.index('salary_max') + 1
cols.insert(idx, 'annual_salary')
df = df[cols]

# %%
#Vamos a modificar esta columna también a integer, como las demás de salarios
df["annual_salary"] = df["annual_salary"].round(0).astype('Int64')

# %% [markdown]
# ###5.4 Creación de la columna "year"

# %%
#Creamos una columna con el año de la publicación para poder distinguir de los datos scrapeados
#y tener la oportunidad de hacer comparaciones temporales

df["publish_date"] = pd.to_datetime(df["publish_date"], errors="coerce")

# %%
df["publish_date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["year"] = df["publish_date"].dt.year

# %%
df["year"].value_counts(dropna=False).sort_index()
# Out:
# year
# 2022    6984
# Name: count, dtype: int64

# %%
#Y ahora cambiamos el orden de las columnas para que publish_date y year aparezcan
#juntas por coherencia

cols = df.columns.tolist()
if "publish_date" in cols:
    cols.remove("publish_date")
idx = cols.index("year")
cols.insert(idx, "publish_date")
df = df[cols]

# %%
df.head()
# Out:
#   country_code                                              title  \
# 0           es                      tecnico gestion de la demanda
# 1           es  java - springboot - proyecto estable - teletra...
# 2           es            consultor sap hana ingles alto (remoto)
# 3           es        android developer. ingles alto. 100% remoto
# 4           es                        analista funcional temporal
#
#                        job_category job_sector  \
# 0  informatica y telecomunicaciones      other
# 1  informatica y telecomunicaciones   software
# 2  informatica y telecomunicaciones      other
# 3  informatica y telecomunicaciones   software
# 4  informatica y telecomunicaciones       data
#
#                                          description  \
# 0  -definicion de roles y escenarios\r    - docum...
# 1  desde agioglobal technology, nos encontramos e...
# 2  airon compañia de innovacion servicios tecnolo...
# 3  desde modis it consultora global especializada...
# 4  nuevas aplicaciones/extension de la funcionali...
#
#                  company_name    city        contract_type   workday  \
# 0  atento españa - estructura  madrid  contrato indefinido  completa
# 1      agio global technology  madrid  contrato indefinido  completa
# 2         airon sistemas s.l.  madrid  contrato indefinido  completa
# 3                       modis  madrid  contrato indefinido  completa
# 4  atento españa - estructura  madrid  contrato indefinido  completa
#
#   position_level   remote  salary_min  salary_max  annual_salary  \
# 0           <NA>  hibrido        <NA>        <NA>           <NA>
# 1           <NA>   remoto       40000       45000          42500
# 2      technical   remoto       27000       30000          28500
# 3      technical   remoto        <NA>        <NA>           <NA>
# 4      technical  hibrido       24000       27000          25500
#
#   salary_period salary_currency salary_type publish_date  year
# 0           NaN             NaN         NaN   2022-07-12  2022
# 1          year             eur       gross   2022-07-12  2022
# 2          year             eur       gross   2022-07-12  2022
# 3           NaN             NaN         NaN   2022-07-12  2022
# 4          year             eur       gross   2022-07-12  2022

# %% [markdown]
# ###5.5 Creación de la columna "source"

# %%
#Creamos una columna llamada source para poder distinguir entre las ofertas
#de nuestro dataset original y las escrapeadas

df["source"] = "dataset"

# %% [markdown]
# ###5.6 Creación de la columna "provincia"

# %%
#Vamos a hacer ahora un mapaedo por provincias a partir de las
#50 ciudades con mayor número de ofertas para maximizar esfuerzos, ya que,
#las demás localidades, tendrían un máximo de 12 ofertas, por lo que el número apenas variaría

df.loc[df["country_code"] == "es", "city"].value_counts().head(50).reset_index()
# Out:
#                                           city  count
# 0                                       madrid   2525
# 1                                    barcelona   1253
# 2                                      sevilla    157
# 3                                     valencia    122
# 4                                     zaragoza     99
# 5                                       bilbao     77
# 6                                   alcobendas     61
# 7                                       malaga     58
# 8                                     a coruña     58
# 9                                  tres cantos     52
# 10                                  valladolid     45
# 11                                      murcia     44
# 12                      donostia-san sebastian     41
# 13                           palma de mallorca     39
# 14                            alicante/alacant     38
# 15                       cornellà de llobregat     37
# 16                              pamplona/iruña     34
# 17                                      getafe     29
# 18                             vitoria-gasteiz     28
# 19                                     granada     23
# 20                      santa cruz de tenerife     22
# 21                          pozuelo de alarcon     22
# 22                                   martorell     20
# 23                         las rozas de madrid     19
# 24                           torrejon de ardoz     19
# 25                                   tarragona     19
# 26  castellon de la plana/castello de la plana     19
# 27                                    albacete     18
# 28                       sant cugat del vallès     18
# 29                                      girona     18
# 30                      santiago de compostela     17
# 31                                     paterna     17
# 32                                   salamanca     17
# 33                  las palmas de gran canaria     16
# 34                                      burgos     16
# 35                                   santander     16
# 36                                     manresa     16
# 37                                        vigo     15
# 38                                     leganes     15
# 39                                  granollers     15
# 40                     san fernando de henares     15
# 41                                    terrassa     14
# 42                                     badajoz     14
# 43                       cerdanyola del vallès     14
# 44                                 guadalajara     13
# 45                                   cartagena     13
# 46                                      lleida     13
# 47                                      oviedo     12
# 48                                     logroño     12
# 49                                       gijon     12

# %%
#Vamos a crear un diccionario de ciudades y su provincia para saber cuáles son
#las 10 provincias con más ofertas y centrarnos en ellas. Incluimos también
#en el diccionario los datos de París y Londres

ciudades_provincias = {
    "madrid": "madrid",
    "alcobendas": "madrid",
    "tres cantos": "madrid",
    "getafe": "madrid",
    "las rozas de madrid": "madrid",
    "pozuelo de alarcon": "madrid",
    "torrejon de ardoz": "madrid",
    "san fernando de henares": "madrid",
    "leganes": "madrid",
    "barcelona": "barcelona",
    "cornellà de llobregat": "barcelona",
    "martorell": "barcelona",
    "tarragona": "tarragona",
    "sant cugat del vallès": "barcelona",
    "girona": "girona",
    "manresa": "barcelona",
    "terrassa": "barcelona",
    "granollers": "barcelona",
    "cerdanyola del vallès": "barcelona",
    "lleida": "lleida",
    "sevilla": "sevilla",
    "malaga": "malaga",
    "granada": "granada",
    "valencia": "valencia",
    "alicante/alacant": "alicante",
    "castellon de la plana/castello de la plana": "castellon",
    "paterna": "valencia",
    "murcia": "murcia",
    "cartagena": "murcia",
    "zaragoza": "zaragoza",
    "oviedo": "asturias",
    "gijon": "asturias",
    "badajoz": "badajoz",
    "albacete": "albacete",
    "guadalajara": "guadalajara",
    "valladolid": "valladolid",
    "salamanca": "salamanca",
    "burgos": "burgos",
    "santander": "cantabria",
    "a coruña": "a coruña",
    "santiago de compostela": "a coruña",
    "vigo": "pontevedra",
    "palma de mallorca": "baleares",
    "santa cruz de tenerife": "santa cruz de tenerife",
    "las palmas de gran canaria": "las palmas",
    "bilbao": "bizkaia",
    "donostia-san sebastian": "guipuzcoa",
    "vitoria-gasteiz": "alava",
    "logroño": "la rioja",
    "pamplona/iruña": "navarra",
    "london, england": "londres",
    "paris": "paris"
}

# %%
#A partir del diccionario, asignamos los datos en una columna nueva
df["provincia"] = df["city"].map(ciudades_provincias)

# %%
#Y colocamos la nueva columna junto a "city"

cols = df.columns.tolist()
if "provincia" in cols:
    cols.remove("provincia")
idx = cols.index("city") + 1
cols.insert(idx, "provincia")
df = df[cols]

# %% [markdown]
# ###5.7 Eliminación de columnas innecesarias

# %%
"""Vamos a eliminar ahora columnas que sabemos que no necesitamos y para poder tener la misma
estructura con los datos scrapeados

-Description --> Columna con demasiado texto libre de la que no se pueden extraer datos claro.
La columna de title ya nos aporta la información que necesitamos.

-Salary_period --> Hecha la conversión a salario anual, no necesitamos tenerla, ya que no vamos a
distinguir entre ofertas mensuales de anuales

-Salary_type --> Esta columna solo contenía los valores "NaN" y "Gross",
por lo que realmente no nos está aportando información
"""

df = df.drop(columns=["description", "salary_period", "salary_type"])

# %%
#Verificamos los cambios incorporados
df.head()
# Out:
#   country_code                                              title  \
# 0           es                      tecnico gestion de la demanda
# 1           es  java - springboot - proyecto estable - teletra...
# 2           es            consultor sap hana ingles alto (remoto)
# 3           es        android developer. ingles alto. 100% remoto
# 4           es                        analista funcional temporal
#
#                        job_category job_sector                company_name  \
# 0  informatica y telecomunicaciones      other  atento españa - estructura
# 1  informatica y telecomunicaciones   software      agio global technology
# 2  informatica y telecomunicaciones      other         airon sistemas s.l.
# 3  informatica y telecomunicaciones   software                       modis
# 4  informatica y telecomunicaciones       data  atento españa - estructura
#
#      city provincia        contract_type   workday position_level   remote  \
# 0  madrid    madrid  contrato indefinido  completa           <NA>  hibrido
# 1  madrid    madrid  contrato indefinido  completa           <NA>   remoto
# 2  madrid    madrid  contrato indefinido  completa      technical   remoto
# 3  madrid    madrid  contrato indefinido  completa      technical   remoto
# 4  madrid    madrid  contrato indefinido  completa      technical  hibrido
#
#    salary_min  salary_max  annual_salary salary_currency publish_date  year  \
# 0        <NA>        <NA>           <NA>             NaN   2022-07-12  2022
# 1       40000       45000          42500             eur   2022-07-12  2022
# 2       27000       30000          28500             eur   2022-07-12  2022
# 3        <NA>        <NA>           <NA>             NaN   2022-07-12  2022
# 4       24000       27000          25500             eur   2022-07-12  2022
#
#     source
# 0  dataset
# 1  dataset
# 2  dataset
# 3  dataset
# 4  dataset

# %% [markdown]
# ## 6.Corrección de outliers

# %% [markdown]
# ### 6.1 Corrección de sueldos más bajos

# %%
#Vamos a centrarnos ahora en los sueldos más bajos.
#Utilizamos "12000" por ser el SMI en 2022 (usamos "12000" porque hemos hecho la conversión por 12 meses)
sueldos_mas_bajos = df[(df["annual_salary"] < 12000)]
sueldos_mas_bajos
# Out:
#      country_code                                              title  \
# 201            es  tecnico informatico de sistemas y redes (parci...
# 926            es  practicas con tecnologias microsoft barcelona ...
# 1046           es      tecnico/a informatica - it support con ingles
# 1734           es                          becario/a.- mantenimiento
# 2018           es                               beca desarrollador/a
# 2049           es  beca ingeniera industrial ade + pase a plantil...
# 2086           es                         gestor/a telefonico orange
# 2686           es                becario / becaria analisis de datos
# 2715           es                                      becario/a it.
# 2796           es             beca developer/desarrollador microsoft
# 2990           es                           beca services & security
# 2991           es                           beca operations analysis
# 2997           es                         beca institutional affairs
# 3066           es                         tecnico_cafeteras_pirineos
# 3413           es                  beca ingenieria industrial - vigo
# 3537           es                  consultor funcional preventas b2b
# 4492           es               practicas consultoria funcional erps
# 4588           es                        beca programacion java j2ee
# 4639           es  practicas con tecnologias microsoft sevilla_oc...
# 4852           es  ayudante reparacion telefonia movil e informatica
# 5013           es  practicas con tecnologias microsoft madrid (oc...
# 5048           es         tecnico/a informatico/a - administrativo/a
# 5085           es                           product owner internship
# 5187           es                    atencion informatica a clientes
# 6716           es        operario/a mantenimiento planta de residuos
# 6719           es                               conductor/a (cuenca)
# 6992           es                operador servicedesk monitorizacion
# 7071           es                              teleoperador/a orange
# 7691           es  becario/a ingenieria quimica de ofertas y proy...
# 7775           es                   beca ingeniero ferroviario /rams
# 7912           es     becario-a ingenieria automatizacion industrial
# 8322           es                                 becario/a forestal
# 8656           es                         beca it business solutions
# 8695           es                practicas consultoria funcional erp
#
#                           job_category job_sector  \
# 201   informatica y telecomunicaciones   software
# 926   informatica y telecomunicaciones      other
# 1046  informatica y telecomunicaciones   software
# 1734             ingenieros y tecnicos      other
# 2018  informatica y telecomunicaciones   software
# 2049             ingenieros y tecnicos      other
# 2086  informatica y telecomunicaciones      other
# 2686  informatica y telecomunicaciones       data
# 2715  informatica y telecomunicaciones   software
# 2796  informatica y telecomunicaciones   software
# 2990             ingenieros y tecnicos      other
# 2991             ingenieros y tecnicos      other
# 2997             ingenieros y tecnicos      other
# 3066             ingenieros y tecnicos      other
# 3413             ingenieros y tecnicos      other
# 3537             ingenieros y tecnicos      other
# 4492  informatica y telecomunicaciones      other
# 4588  informatica y telecomunicaciones   software
# 4639  informatica y telecomunicaciones      other
# 4852             ingenieros y tecnicos      other
# 5013  informatica y telecomunicaciones      other
# 5048  informatica y telecomunicaciones   software
# 5085  informatica y telecomunicaciones      other
# 5187  informatica y telecomunicaciones      other
# 6716             ingenieros y tecnicos      other
# 6719             ingenieros y tecnicos      other
# 6992  informatica y telecomunicaciones      other
# 7071  informatica y telecomunicaciones      other
# 7691             ingenieros y tecnicos      other
# 7775             ingenieros y tecnicos      other
# 7912             ingenieros y tecnicos      other
# 8322             ingenieros y tecnicos      other
# 8656  informatica y telecomunicaciones   software
# 8695  informatica y telecomunicaciones      other
#
#                             company_name                     city  \
# 201                                tipsa  san fernando de henares
# 926                        avanade spain                barcelona
# 1046     core & global, it solutions, sa                barcelona
# 1734                        elecnor, s.a     mairena del aljarafe
# 2018                          madison mk               valladolid
# 2049                                 gls  san fernando de henares
# 2086                              adecco              guadalajara
# 2686                     grupo diusframi                   madrid
# 2715  man south europe medical institute                   madrid
# 2796                            prodware   donostia-san sebastian
# 2990                            randstad                   madrid
# 2991                            randstad                barcelona
# 2997                            randstad                barcelona
# 3066                            prosales                 pirineos
# 3413                        id logistics                     vigo
# 3537                          experis it                   madrid
# 4492                          pkf attest                   madrid
# 4588                              tecnoy                   madrid
# 4639                       avanade spain                  sevilla
# 4852             elena martinez gonzalez                  logroño
# 5013                       avanade spain                   madrid
# 5048                       grupo solutia                  sevilla
# 5085         hr ai solutions factory sl.                   madrid
# 5187                        dualred s.l.                 valencia
# 6716                  griño ecologic, sa                constanti
# 6719              ilunion sociosanitario                   cuenca
# 6992                        trs staffing                 zaragoza
# 7071      isgf informes comerciales s.l.         alicante/alacant
# 7691                  keiken engineering               alcobendas
# 7775                            exceltic                   madrid
# 7912                 mitsubishi electric    sant cugat del vallès
# 8322              magnon green energy sl              puertollano
# 8656                             logista                  leganes
# 8695                          pkf attest                  sevilla
#
#         provincia                     contract_type   workday position_level  \
# 201        madrid          contrato otros contratos   parcial      technical
# 926     barcelona         contrato a tiempo parcial   parcial     internship
# 1046    barcelona         contrato a tiempo parcial   parcial           <NA>
# 1734          NaN          contrato otros contratos   parcial           <NA>
# 2018   valladolid                contrato formativo  completa     internship
# 2049       madrid                contrato formativo  completa     internship
# 2086  guadalajara  contrato de duracion determinada   parcial           <NA>
# 2686       madrid  contrato de duracion determinada  completa           <NA>
# 2715       madrid                contrato formativo   parcial           <NA>
# 2796    guipuzcoa  contrato de duracion determinada  completa     internship
# 2990       madrid  contrato de duracion determinada  completa     internship
# 2991    barcelona  contrato de duracion determinada  completa     internship
# 2997    barcelona  contrato de duracion determinada  completa     internship
# 3066          NaN         contrato fijo discontinuo  completa           <NA>
# 3413   pontevedra                contrato formativo  completa     internship
# 3537       madrid               contrato indefinido  completa      technical
# 4492       madrid                contrato formativo  completa     internship
# 4588       madrid          contrato otros contratos   parcial     internship
# 4639      sevilla         contrato a tiempo parcial   parcial     internship
# 4852     la rioja               contrato indefinido   parcial           <NA>
# 5013       madrid         contrato a tiempo parcial   parcial     internship
# 5048      sevilla               contrato indefinido  completa           <NA>
# 5085       madrid                contrato formativo  completa     internship
# 5187     valencia         contrato a tiempo parcial   parcial           <NA>
# 6716          NaN               contrato indefinido  completa           <NA>
# 6719          NaN  contrato de duracion determinada      otra           <NA>
# 6992     zaragoza               contrato indefinido  completa           <NA>
# 7071     alicante               contrato indefinido   parcial           <NA>
# 7691       madrid          contrato otros contratos   parcial           <NA>
# 7775       madrid                contrato formativo  completa     internship
# 7912    barcelona                contrato formativo      otra           <NA>
# 8322          NaN          contrato otros contratos  completa           <NA>
# 8656       madrid                contrato formativo  completa     internship
# 8695      sevilla                contrato formativo  completa     internship
#
#             remote  salary_min  salary_max  annual_salary salary_currency  \
# 201     presencial       10000       12000          11000             eur
# 926   no publicado         600         900           9000             eur
# 1046    presencial        8000       12000          10000             eur
# 1734    presencial         450         600           6300             eur
# 2018    presencial         600         600           7200             eur
# 2049    presencial         600         900           9000             eur
# 2086    presencial       10000       12000          11000             eur
# 2686       hibrido         450        1200           9900             eur
# 2715    presencial         600         600           7200             eur
# 2796       hibrido         900         900          10800             eur
# 2990       hibrido         900         900          10800             eur
# 2991       hibrido         900         900          10800             eur
# 2997       hibrido         900         900          10800             eur
# 3066    presencial         450         900           8100             eur
# 3413    presencial       10000        <NA>          10000             eur
# 3537  no publicado          35        <NA>             35             eur
# 4492    presencial         600         900           9000             eur
# 4588    presencial         450         450           5400             eur
# 4639    presencial         450         450           5400             eur
# 4852    presencial         600         900           9000             eur
# 5013        remoto         450         450           5400             eur
# 5048    presencial       10000        <NA>          10000             eur
# 5085       hibrido         600         600           7200             eur
# 5187    presencial         600         600           7200             eur
# 6716    presencial       10000        <NA>          10000             eur
# 6719    presencial        6000        8000           7000             eur
# 6992    presencial       10000        <NA>          10000             eur
# 7071    presencial       10000       12000          11000             eur
# 7691    presencial        6000        6000           6000             eur
# 7775       hibrido         600         900           9000             eur
# 7912       hibrido         600        1200          10800             eur
# 8322    presencial         600         900           9000             eur
# 8656    presencial         600         900           9000             eur
# 8695    presencial         600         900           9000             eur
#
#      publish_date  year   source
# 201    2022-07-11  2022  dataset
# 926    2022-07-28  2022  dataset
# 1046   2022-07-28  2022  dataset
# 1734   2022-08-20  2022  dataset
# 2018   2022-07-14  2022  dataset
# 2049   2022-07-21  2022  dataset
# 2086   2022-07-13  2022  dataset
# 2686   2022-06-30  2022  dataset
# 2715   2022-06-30  2022  dataset
# 2796   2022-06-30  2022  dataset
# 2990   2022-06-29  2022  dataset
# 2991   2022-06-29  2022  dataset
# 2997   2022-06-29  2022  dataset
# 3066   2022-08-24  2022  dataset
# 3413   2022-07-18  2022  dataset
# 3537   2022-07-18  2022  dataset
# 4492   2022-07-04  2022  dataset
# 4588   2022-07-04  2022  dataset
# 4639   2022-07-04  2022  dataset
# 4852   2022-07-09  2022  dataset
# 5013   2022-07-11  2022  dataset
# 5048   2022-07-11  2022  dataset
# 5085   2022-07-11  2022  dataset
# 5187   2022-07-11  2022  dataset
# 6716   2022-07-22  2022  dataset
# 6719   2022-07-22  2022  dataset
# 6992   2022-08-11  2022  dataset
# 7071   2022-08-11  2022  dataset
# 7691   2022-08-26  2022  dataset
# 7775   2022-08-26  2022  dataset
# 7912   2022-08-25  2022  dataset
# 8322   2022-08-17  2022  dataset
# 8656   2022-07-07  2022  dataset
# 8695   2022-07-07  2022  dataset

# %%
#Veamos ahora si esos valores bajos permanecen o no, aplicando filtros de campos que suelen llevar aparejados
#sueldos más bajos, así que nos quedamos con trabajos que no sean de prácticas, pero tengan jornada completa
sueldos_mas_bajos_annual = df[(df["annual_salary"] < 12000) & (df["workday"] == "completa") & (df["contract_type"] != "contrato formativo")]
sueldos_mas_bajos_annual
# Out:
#      country_code                                        title  \
# 2686           es          becario / becaria analisis de datos
# 2796           es       beca developer/desarrollador microsoft
# 2990           es                     beca services & security
# 2991           es                     beca operations analysis
# 2997           es                   beca institutional affairs
# 3066           es                   tecnico_cafeteras_pirineos
# 3537           es            consultor funcional preventas b2b
# 5048           es   tecnico/a informatico/a - administrativo/a
# 6716           es  operario/a mantenimiento planta de residuos
# 6992           es          operador servicedesk monitorizacion
# 8322           es                           becario/a forestal
#
#                           job_category job_sector            company_name  \
# 2686  informatica y telecomunicaciones       data         grupo diusframi
# 2796  informatica y telecomunicaciones   software                prodware
# 2990             ingenieros y tecnicos      other                randstad
# 2991             ingenieros y tecnicos      other                randstad
# 2997             ingenieros y tecnicos      other                randstad
# 3066             ingenieros y tecnicos      other                prosales
# 3537             ingenieros y tecnicos      other              experis it
# 5048  informatica y telecomunicaciones   software           grupo solutia
# 6716             ingenieros y tecnicos      other      griño ecologic, sa
# 6992  informatica y telecomunicaciones      other            trs staffing
# 8322             ingenieros y tecnicos      other  magnon green energy sl
#
#                         city  provincia                     contract_type  \
# 2686                  madrid     madrid  contrato de duracion determinada
# 2796  donostia-san sebastian  guipuzcoa  contrato de duracion determinada
# 2990                  madrid     madrid  contrato de duracion determinada
# 2991               barcelona  barcelona  contrato de duracion determinada
# 2997               barcelona  barcelona  contrato de duracion determinada
# 3066                pirineos        NaN         contrato fijo discontinuo
# 3537                  madrid     madrid               contrato indefinido
# 5048                 sevilla    sevilla               contrato indefinido
# 6716               constanti        NaN               contrato indefinido
# 6992                zaragoza   zaragoza               contrato indefinido
# 8322             puertollano        NaN          contrato otros contratos
#
#        workday position_level        remote  salary_min  salary_max  \
# 2686  completa           <NA>       hibrido         450        1200
# 2796  completa     internship       hibrido         900         900
# 2990  completa     internship       hibrido         900         900
# 2991  completa     internship       hibrido         900         900
# 2997  completa     internship       hibrido         900         900
# 3066  completa           <NA>    presencial         450         900
# 3537  completa      technical  no publicado          35        <NA>
# 5048  completa           <NA>    presencial       10000        <NA>
# 6716  completa           <NA>    presencial       10000        <NA>
# 6992  completa           <NA>    presencial       10000        <NA>
# 8322  completa           <NA>    presencial         600         900
#
#       annual_salary salary_currency publish_date  year   source
# 2686           9900             eur   2022-06-30  2022  dataset
# 2796          10800             eur   2022-06-30  2022  dataset
# 2990          10800             eur   2022-06-29  2022  dataset
# 2991          10800             eur   2022-06-29  2022  dataset
# 2997          10800             eur   2022-06-29  2022  dataset
# 3066           8100             eur   2022-08-24  2022  dataset
# 3537             35             eur   2022-07-18  2022  dataset
# 5048          10000             eur   2022-07-11  2022  dataset
# 6716          10000             eur   2022-07-22  2022  dataset
# 6992          10000             eur   2022-08-11  2022  dataset
# 8322           9000             eur   2022-08-17  2022  dataset

# %%
#Vemos que hay un resultado con datos 35 al año, lo que parece una errata.
#Vamos a convertirla directamente multiplicando por 100 en ambos df

cols = ["salary_min", "annual_salary"]
df.loc[(df["annual_salary"] == 35) | (df["salary_min"] == 35), cols] *= 1000

# %%
#Observamos también que varias ofertas son de beca, pero no se reflejan como tal en el campo de "contract_type"
#Vamos a modificar este campo para que aparezca como "formativo" en estos casos

filtro_df = df["title"].str.contains("beca|becario", case=False, na=False)
df.loc[filtro_df, "contract_type"] = "contrato formativo"

# %%
#Reejecutamos el filtro anterior para ver los resultados que tenemos ahora

sueldos_mas_bajos_annual = df[(df["annual_salary"] < 12000) & (df["workday"] == "completa") & (df["contract_type"] != "contrato formativo")]
sueldos_mas_bajos_annual
# Out:
#      country_code                                        title  \
# 3066           es                   tecnico_cafeteras_pirineos
# 5048           es   tecnico/a informatico/a - administrativo/a
# 6716           es  operario/a mantenimiento planta de residuos
# 6992           es          operador servicedesk monitorizacion
#
#                           job_category job_sector        company_name  \
# 3066             ingenieros y tecnicos      other            prosales
# 5048  informatica y telecomunicaciones   software       grupo solutia
# 6716             ingenieros y tecnicos      other  griño ecologic, sa
# 6992  informatica y telecomunicaciones      other        trs staffing
#
#            city provincia              contract_type   workday position_level  \
# 3066   pirineos       NaN  contrato fijo discontinuo  completa           <NA>
# 5048    sevilla   sevilla        contrato indefinido  completa           <NA>
# 6716  constanti       NaN        contrato indefinido  completa           <NA>
# 6992   zaragoza  zaragoza        contrato indefinido  completa           <NA>
#
#           remote  salary_min  salary_max  annual_salary salary_currency  \
# 3066  presencial         450         900           8100             eur
# 5048  presencial       10000        <NA>          10000             eur
# 6716  presencial       10000        <NA>          10000             eur
# 6992  presencial       10000        <NA>          10000             eur
#
#      publish_date  year   source
# 3066   2022-08-24  2022  dataset
# 5048   2022-07-11  2022  dataset
# 6716   2022-07-22  2022  dataset
# 6992   2022-08-11  2022  dataset

# %%
#El primer resultado tiene sentido, porque, aunque sea jornada completa, es fijo discontinuo.
#Sin embargo, en los otros tres casos, no hay motivos para mantener "10000", así que vamos a cambiar a 12000

filtro_smi = (
    (df["annual_salary"] == 10000) &
    (df["workday"] == "jornada completa") &
    (df["contract_type"] == "contrato indefinido")
)
df.loc[filtro_smi, ["annual_salary", "salary_min"]] = 12000

# %% [markdown]
# ### 6.2 Corrección de sueldos más altos

# %%
#Veamos ahora los sueldos más altos
sueldos_mas_altos = df[(df["annual_salary"] > 100000)]
sueldos_mas_altos
# Out:
#      country_code                                              title  \
# 3810           fr  business / data analyst - anglais courant / fr...
# 3812           fr           devops senior cloud/back end / freelance
# 3814           fr               data engineer aws senior / freelance
# 5287           fr        business analyst - summit front / freelance
# 5291           fr  business analyst summit front - fixed income &...
# 5940           uk                                       test analyst
# 6140           uk                                   ibcm controls vp
# 6145           uk                         senior java developer (sc)
# 6152           uk                                  hr m&a - director
# 6237           uk                           hr m&a - senior director
# 7820           uk                          software engineer (staff)
# 7834           uk                                 enablement manager
# 7860           uk        technical delivery manager/ project manager
# 7870           uk                                 enablement manager
# 7941           uk                            corporate legal counsel
# 7958           uk  enterprise account executive (oracle sales) - ...
# 8003           uk    senior software engineer (c#, .net core, azure)
# 8972           uk                       immigration knowledge lawyer
# 9336           fr      (bruxelles) business analyst secteur bancaire
# 9374           fr                      attache commercial en gms h/f
# 9722           fr  application owner - application de souscriptio...
# 9725           fr            product owner (produit web) / freelance
# 9848           uk         sales operations - graduate (uk) | thefork
# 9871           uk                            aem solutions architect
#
#                  job_category job_sector              company_name  \
# 3810  management & consulting       data                 micropole
# 3812  management & consulting   software                 micropole
# 3814  management & consulting       data                 micropole
# 5287  management & consulting       data                   nexoris
# 5291  management & consulting       data                   nexoris
# 5940  management & consulting       data    pertemps network group
# 6140  management & consulting  executive              michael page
# 6145  management & consulting   software                 accenture
# 6152  management & consulting  executive                       wtw
# 6237  management & consulting  executive                       wtw
# 7820   information technology   software                   vaticle
# 7834   information technology      other            content square
# 7860   information technology      other                 synechron
# 7870   information technology      other             contentsquare
# 7941   information technology      other           careers at tide
# 7958   information technology      other           insightsoftware
# 8003   information technology   software                  aubay uk
# 8972  management & consulting      other              michael page
# 9336  management & consulting       data             bk consulting
# 9374  management & consulting      other  impact sales & marketing
# 9722   information technology      other                 groupe hn
# 9725   information technology      other                    teolia
# 9848   information technology      other               tripadvisor
# 9871   information technology      other                netcentric
#
#                  city provincia contract_type       workday position_level  \
# 3810            paris     paris  no publicado  no publicado      technical
# 3812            paris     paris  no publicado  no publicado      technical
# 3814            paris     paris  no publicado  no publicado      technical
# 5287            paris     paris  no publicado  no publicado      technical
# 5291            paris     paris  no publicado  no publicado      technical
# 5940  london, england   londres  no publicado  no publicado      technical
# 6140  london, england   londres  no publicado  no publicado      executive
# 6145  london, england   londres  no publicado  no publicado      technical
# 6152  london, england   londres  no publicado  no publicado      executive
# 6237  london, england   londres  no publicado  no publicado      executive
# 7820  london, england   londres  no publicado  no publicado      technical
# 7834  london, england   londres  no publicado  no publicado     management
# 7860  london, england   londres  no publicado  no publicado     management
# 7870  london, england   londres  no publicado  no publicado     management
# 7941  london, england   londres  no publicado  no publicado           <NA>
# 7958  london, england   londres  no publicado  no publicado           <NA>
# 8003  london, england   londres  no publicado  no publicado      technical
# 8972  london, england   londres  no publicado  no publicado           <NA>
# 9336            paris     paris  no publicado  no publicado      technical
# 9374            paris     paris  no publicado  no publicado           <NA>
# 9722            paris     paris  no publicado  no publicado           <NA>
# 9725            paris     paris  no publicado  no publicado           <NA>
# 9848  london, england   londres  no publicado  no publicado           <NA>
# 9871  london, england   londres  no publicado  no publicado           <NA>
#
#             remote  salary_min  salary_max  annual_salary salary_currency  \
# 3810  no publicado      130000      153400         141700             eur
# 3812  no publicado      130000      156000         143000             eur
# 3814  no publicado      153400      169000         161200             eur
# 5287  no publicado      143000      153400         148200             eur
# 5291  no publicado      143000      153400         148200             eur
# 5940  no publicado      110500      110500         110500             gbp
# 6140  no publicado      208000      260000         234000             gbp
# 6145  no publicado      208000      208000         208000             gbp
# 6152  no publicado      111752      111752         111752             gbp
# 6237  no publicado      111752      111752         111752             gbp
# 7820  no publicado      110000      130000         120000             gbp
# 7834  no publicado      106270      121852         114061             gbp
# 7860  no publicado       95000      105608         100304             gbp
# 7870  no publicado      106270      121852         114061             gbp
# 7941  no publicado      113646      132715         123180             gbp
# 7958  no publicado       87162      147960         117561             gbp
# 8003  no publicado      110000      120000         115000             gbp
# 8972  no publicado      105000      115000         110000             gbp
# 9336  no publicado      117000      234000         175500             eur
# 9374  no publicado      240000      276000         258000             eur
# 9722  no publicado      104000      158600         131300             eur
# 9725  no publicado      130000      171600         150800             eur
# 9848  no publicado      105975      105975         105975             gbp
# 9871  no publicado      130120      130120         130120             gbp
#
#      publish_date  year   source
# 3810   2022-08-13  2022  dataset
# 3812   2022-08-13  2022  dataset
# 3814   2022-08-13  2022  dataset
# 5287   2022-08-20  2022  dataset
# 5291   2022-08-20  2022  dataset
# 5940   2022-08-17  2022  dataset
# 6140   2022-08-17  2022  dataset
# 6145   2022-08-17  2022  dataset
# 6152   2022-08-17  2022  dataset
# 6237   2022-08-17  2022  dataset
# 7820   2022-08-17  2022  dataset
# 7834   2022-08-17  2022  dataset
# 7860   2022-08-17  2022  dataset
# 7870   2022-08-17  2022  dataset
# 7941   2022-08-17  2022  dataset
# 7958   2022-08-17  2022  dataset
# 8003   2022-08-17  2022  dataset
# 8972   2022-08-25  2022  dataset
# 9336   2022-08-30  2022  dataset
# 9374   2022-08-30  2022  dataset
# 9722   2022-08-30  2022  dataset
# 9725   2022-08-30  2022  dataset
# 9848   2022-08-29  2022  dataset
# 9871   2022-08-29  2022  dataset

# %%
"""Un dato interesante que tenemos de partida es que todas las ofertas con un sueldo superior
a 100000 es que todas se encuentran fuera de España, a pesar de que sea el país mayoritario
por número de ofertas.
En lo que respecta a outliers erróneos, podemos ver claramente el caso de París para el puesto
"attache commercial en gms h/f" (gestor comercial de ventas), así que vamos a dividir por 10 en este caso
"""

cols = ["salary_min", "salary_max", "annual_salary"]
df.loc[(df["annual_salary"] == 258000) | (df["salary_max"] == 276000) | (df["salary_min"] == 240000), cols] /= 10

# %%
df.head()
# Out:
#   country_code                                              title  \
# 0           es                      tecnico gestion de la demanda
# 1           es  java - springboot - proyecto estable - teletra...
# 2           es            consultor sap hana ingles alto (remoto)
# 3           es        android developer. ingles alto. 100% remoto
# 4           es                        analista funcional temporal
#
#                        job_category job_sector                company_name  \
# 0  informatica y telecomunicaciones      other  atento españa - estructura
# 1  informatica y telecomunicaciones   software      agio global technology
# 2  informatica y telecomunicaciones      other         airon sistemas s.l.
# 3  informatica y telecomunicaciones   software                       modis
# 4  informatica y telecomunicaciones       data  atento españa - estructura
#
#      city provincia        contract_type   workday position_level   remote  \
# 0  madrid    madrid  contrato indefinido  completa           <NA>  hibrido
# 1  madrid    madrid  contrato indefinido  completa           <NA>   remoto
# 2  madrid    madrid  contrato indefinido  completa      technical   remoto
# 3  madrid    madrid  contrato indefinido  completa      technical   remoto
# 4  madrid    madrid  contrato indefinido  completa      technical  hibrido
#
#    salary_min  salary_max  annual_salary salary_currency publish_date  year  \
# 0        <NA>        <NA>           <NA>             NaN   2022-07-12  2022
# 1       40000       45000          42500             eur   2022-07-12  2022
# 2       27000       30000          28500             eur   2022-07-12  2022
# 3        <NA>        <NA>           <NA>             NaN   2022-07-12  2022
# 4       24000       27000          25500             eur   2022-07-12  2022
#
#     source
# 0  dataset
# 1  dataset
# 2  dataset
# 3  dataset
# 4  dataset
